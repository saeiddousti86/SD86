# %% [markdown]
# # Question 3

# %% [markdown]
# This dataset contains five year's worth of H-1B petition data, with approximately 3 million records overall. The columns in the dataset include case status, employer name, worksite coordinates, job title, prevailing wage, occupation code, and year filed.
#
# For more information on individual columns, refer to the column metadata. A detailed description of the underlying raw dataset is available in an official data dictionary.

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('h1b_kaggle.csv')

# %%
df.tail(20)
# Out:
#          Unnamed: 0 CASE_STATUS                      EMPLOYER_NAME  \
# 3002438     3002439   WITHDRAWN              CANVAS INFOTECH, INC.
# 3002439     3002440   WITHDRAWN                NEW YORK UNIVERSITY
# 3002440     3002441   WITHDRAWN               ORACLE AMERICA, INC.
# 3002441     3002442   WITHDRAWN                 B & D DENTAL CORP.
# 3002442     3002443   WITHDRAWN  MEDTECH STAFFING & SOLUTIONS, INC
# 3002443     3002444   WITHDRAWN            LARSEN & TOUBRO LIMITED
# 3002444     3002445   WITHDRAWN            LARSEN & TOUBRO LIMITED
# 3002445     3002446         NaN                                NaN
# 3002446     3002447         NaN                                NaN
# 3002447     3002448         NaN                                NaN
# 3002448     3002449         NaN                                NaN
# 3002449     3002450         NaN                                NaN
# 3002450     3002451         NaN                                NaN
# ...

# %%
df['CASE_STATUS'].unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED', nan], dtype=object)

# %%
df.drop( df[(df['CASE_STATUS']).isnull() ].index ,  axis=0, inplace=True)

# %%
df
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# 5                 6  CERTIFIED-WITHDRAWN
# 6                 7  CERTIFIED-WITHDRAWN
# 7                 8  CERTIFIED-WITHDRAWN
# 8                 9  CERTIFIED-WITHDRAWN
# 9                10            WITHDRAWN
# 10               11  CERTIFIED-WITHDRAWN
# 11               12  CERTIFIED-WITHDRAWN
# 12               13  CERTIFIED-WITHDRAWN
# 13               14  CERTIFIED-WITHDRAWN
# 14               15  CERTIFIED-WITHDRAWN
# 15               16  CERTIFIED-WITHDRAWN
# 16               17  CERTIFIED-WITHDRAWN
# 17               18  CERTIFIED-WITHDRAWN
# 18               19            CERTIFIED
# 19               20            CERTIFIED
# 20               21  CERTIFIED-WITHDRAWN
# 21               22  CERTIFIED-WITHDRAWN
# ...

# %%
df['YEAR'] = ( df['YEAR'] ).astype(int)

# %%
df_2 = df.copy()

# %%
df_2
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# 5                 6  CERTIFIED-WITHDRAWN
# 6                 7  CERTIFIED-WITHDRAWN
# 7                 8  CERTIFIED-WITHDRAWN
# 8                 9  CERTIFIED-WITHDRAWN
# 9                10            WITHDRAWN
# 10               11  CERTIFIED-WITHDRAWN
# 11               12  CERTIFIED-WITHDRAWN
# 12               13  CERTIFIED-WITHDRAWN
# 13               14  CERTIFIED-WITHDRAWN
# 14               15  CERTIFIED-WITHDRAWN
# 15               16  CERTIFIED-WITHDRAWN
# 16               17  CERTIFIED-WITHDRAWN
# 17               18  CERTIFIED-WITHDRAWN
# 18               19            CERTIFIED
# 19               20            CERTIFIED
# 20               21  CERTIFIED-WITHDRAWN
# 21               22  CERTIFIED-WITHDRAWN
# ...

# %%
plt.scatter(df_2['YEAR'],df_2['PREVAILING_WAGE'])
plt.xlabel('Year', fontsize=20);
plt.ylabel('PREVAILING WAGE', fontsize=20);
